# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpendracse/DataAnalyst/blob/main/Pandas_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Data Set/imdb_data.csv'

df = pd.read_csv(path)
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# ## **Yesterday, we learnt a little about the very useful library Pandas widely used for Data Analysis. It is time to put the many utilities of this library in front of our eyes. We will be performing following manipulations and exploration of our data:**
#
# * ### Indexing and slicing operations
# * ### Manipulating columns
# * ### Exploring unique and missing values

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# # <u>**<code>describe()</code>**</u>
#
# ## This method gives the overall descriptive summary of the dataframe. This works only for numerical columns

# %%
3.000000e+03
# Out:
# 3000.0

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
3.800000e+08
# Out:
# 380000000.0

# %%
3.800000*100000000
# Out:
# 380000000.0

# %% [markdown]
# # <u>**Indexing and Slicing**</u>

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# ## **<code>iloc</code>** gets rows (or columns) at particular positions in the index (so it only takes integers).

# %%
#df.iloc[rows,columns]

# %%
df.iloc[:8,2:5]
# Out:
#      budget                                             genres  \
# 0  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5   8000000  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  14000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7         0                [{'id': 99, 'name': 'Documentary'}]
#
#                              homepage
# 0                                 NaN
# 1                                 NaN
# 2   http://sonyclassics.com/whiplash/
# 3          http://kahaanithefilm.com/
# 4                                 NaN
# 5                                 NaN
# 6  http://www.thepossessionmovie.com/
# 7                                 NaN

# %% [markdown]
# ## **<code>loc</code>** gets rows (or columns) with particular labels from the index.

# %%
df.loc[:5,['title','budget','genres']]
# Out:
#                                       title    budget  \
# 0                    Hot Tub Time Machine 2  14000000
# 1  The Princess Diaries 2: Royal Engagement  40000000
# 2                                  Whiplash   3300000
# 3                                   Kahaani   1200000
# 4                                Marine Boy         0
# 5    Pinocchio and the Emperor of the Night   8000000
#
#                                               genres
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...

# %%
df.loc[:,['title','budget','genres']]
# Out:
#                                          title    budget  \
# 0                       Hot Tub Time Machine 2  14000000
# 1     The Princess Diaries 2: Royal Engagement  40000000
# 2                                     Whiplash   3300000
# 3                                      Kahaani   1200000
# 4                                   Marine Boy         0
# ...                                        ...       ...
# 2995                                   Chasers         0
# 2996                          We Are the Best!         0
# 2997                   The Long Kiss Goodnight  65000000
# 2998                          Along Came Polly  42000000
# 2999                                 Abduction  35000000
#
#                                                  genres
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df[['title','budget','original_language']]
# Out:
#                                          title    budget original_language
# 0                       Hot Tub Time Machine 2  14000000                en
# 1     The Princess Diaries 2: Royal Engagement  40000000                en
# 2                                     Whiplash   3300000                en
# 3                                      Kahaani   1200000                hi
# 4                                   Marine Boy         0                ko
# ...                                        ...       ...               ...
# 2995                                   Chasers         0                en
# 2996                          We Are the Best!         0                sv
# 2997                   The Long Kiss Goodnight  65000000                en
# 2998                          Along Came Polly  42000000                en
# 2999                                 Abduction  35000000                en
#
# [3000 rows x 3 columns]

# %% [markdown]
# ## <b>In fact we can also perform boolean indexing on our dataframe</b>

# %%
df['original_language'].value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: count, dtype: int64

# %%
hindi_movies = df[df['original_language'] == 'hi']
hindi_movies.head()
# Out:
#       id belongs_to_collection    budget  \
# 3      4                   NaN   1200000
# 213  214                   NaN   6700000
# 371  372                   NaN  13100000
# 401  402                   NaN   3000000
# 419  420                   NaN   3750000
#
#                                                 genres  \
# 3    [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 213                     [{'id': 28, 'name': 'Action'}]
# 371  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419  [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
#
#                             homepage    imdb_id original_language  \
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 213                              NaN  tt2077833                hi
# 371  http://www.thankyouthefilm.com/  tt1720254                hi
# 401                              NaN  tt0319736                hi
# ...

# %%
hindi_movies.shape
# Out:
# (42, 23)

# %%
hindi_movies[['title','original_language']]
# Out:
#                                  title original_language
# 3                              Kahaani                hi
# 213                      Rowdy Rathore                hi
# 371                          Thank You                hi
# 401         The Legend of Bhagat Singh                hi
# 419   Dear Guest, When Will You Leave?                hi
# 481             Chandni Chowk To China                hi
# 585                             Dangal                hi
# 627                                Fan                hi
# 671                    Anjaana Anjaani                hi
# 695                          Tere Naam                hi
# 771                            Kaminey                hi
# 840                             Neerja                hi
# 848                         Raanjhanaa                hi
# 970                          Heropanti                hi
# 1004                      The Lunchbox                hi
# ...

# %%
english_movies = df[df['original_language'] == 'en'][['title','original_language']]
english_movies.head()
# Out:
#                                       title original_language
# 0                    Hot Tub Time Machine 2                en
# 1  The Princess Diaries 2: Royal Engagement                en
# 2                                  Whiplash                en
# 5    Pinocchio and the Emperor of the Night                en
# 6                            The Possession                en

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
long_movies = df[df['runtime']>150][['title','runtime','original_language']]
long_movies
# Out:
#                           title  runtime original_language
# 47            The Hateful Eight    167.0                en
# 51               The Great Race    160.0                en
# 76    Kandukondain Kandukondain    157.0                ta
# 97                       Target    158.0                ru
# 107                  Braveheart    177.0                en
# ...                         ...      ...               ...
# 2860                     Gandhi    191.0                en
# 2877                    Amadeus    160.0                en
# 2932           The Sand Pebbles    182.0                en
# 2944             Apocalypse Now    153.0                en
# 2965             Les Misérables    157.0                en
#
# [127 rows x 3 columns]

# %%
long_movies[long_movies['original_language'] == 'en']
# Out:
#                                                   title  runtime  \
# 47                                    The Hateful Eight    167.0
# 51                                       The Great Race    160.0
# 107                                          Braveheart    177.0
# 109                                              Hawaii    189.0
# 114   The Lord of the Rings: The Fellowship of the Ring    178.0
# ...                                                 ...      ...
# 2860                                             Gandhi    191.0
# 2877                                            Amadeus    160.0
# 2932                                   The Sand Pebbles    182.0
# 2944                                     Apocalypse Now    153.0
# 2965                                     Les Misérables    157.0
#
#      original_language
# 47                  en
# 51                  en
# 107                 en
# 109                 en
# 114                 en
# ...                ...
# ...

# %%
short_english_movies = df[(df['runtime']<50) & (df['original_language'] == 'en')][['title','runtime','original_language']]
short_english_movies
# Out:
#                                               title  runtime original_language
# 775                                 Born to Be Wild     40.0                en
# 1020                                 The Living Sea     40.0                en
# 1874                                        Missing      0.0                en
# 2577  The Life and Death of 9413, a Hollywood Extra     11.0                en
# 2645                               My Old Classmate      0.0                en

# %% [markdown]
# # <u>**Next let us see how we can manipulate columns**</u>

# %%
long_movies = df[(df['original_language'] == 'hi') & (df['runtime'] > 148)][['title','runtime','original_language']]
long_movies.head()
# Out:
#                                 title  runtime original_language
# 401        The Legend of Bhagat Singh    155.0                hi
# 419  Dear Guest, When Will You Leave?    155.0                hi
# 481            Chandni Chowk To China    149.0                hi
# 585                            Dangal    161.0                hi
# 671                   Anjaana Anjaani    151.0                hi

# %% [markdown]
# ## **Let's say if you wanted a new column whose values were half the movie runtime**

# %%
df['runtime']
# Out:
# 0        93.0
# 1       113.0
# 2       105.0
# 3       122.0
# 4       118.0
#         ...
# 2995    102.0
# 2996    102.0
# 2997    120.0
# 2998     90.0
# 2999    106.0
# Name: runtime, Length: 3000, dtype: float64

# %%
df['half_runtime'] = df['runtime']/2

df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime'],
#       dtype='object')

# %%
df['profit'] = df['revenue'] - df['budget']

df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue  \
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09
#
#        half_runtime        profit
# count   2998.000000  3.000000e+03
# mean      53.928286  4.419452e+07
# std       11.043217  1.123274e+08
# min        0.000000 -1.074474e+08
# 25%       47.000000  1.795200e+04
# 50%       52.000000  6.121122e+06
# 75%       59.000000  4.143293e+07
# ...

# %%
df[df['runtime'] == 338][['title','runtime']]
# Out:
#        title  runtime
# 1211  Carlos    338.0

# %%
df['profit'].max()
# Out:
# 1316249360

# %%
df[df['profit'] == 1316249360][['title','profit']]
# Out:
#           title      profit
# 1761  Furious 7  1316249360

# %% [markdown]
# ## **Next, we can also drop some columns which we want to drop**

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime', 'profit'],
#       dtype='object')

# %%
df.drop(['half_runtime','belongs_to_collection'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'budget', 'genres', 'homepage', 'imdb_id', 'original_language',
#        'original_title', 'overview', 'popularity', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'Keywords',
#        'cast', 'crew', 'revenue', 'profit'],
#       dtype='object')

# %% [markdown]
# ## **We can do a lot of basic operations as well**

# %%
df['runtime']
# Out:
# 0        93.0
# 1       113.0
# 2       105.0
# 3       122.0
# 4       118.0
#         ...
# 2995    102.0
# 2996    102.0
# 2997    120.0
# 2998     90.0
# 2999    106.0
# Name: runtime, Length: 3000, dtype: float64

# %%
df['runtime'].sum()
# Out:
# 323354.0

# %%
df['runtime'].min()
# Out:
# 0.0

# %%
df['runtime'].max()
# Out:
# 338.0

# %%
df['runtime'].mean()
# Out:
# 107.85657104736491

# %%
df['runtime'].median()
# Out:
# 104.0

# %%
df['runtime'].count()
# Out:
# 2998

# %%
df[df['id']!=1]
# Out:
#         id    budget                                             genres  \
# 1        2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2        3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3        4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4        5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5        6   8000000  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# ...    ...       ...                                                ...
# 2995  2996         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  2997         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  2998  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  2999  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  3000  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# ...

# %%
import numpy as np

# %%
from skimage import data
camera = data.camera()

# %%
camera.shape
# Out:
# (512, 512)

# %%
camera
# Out:
# array([[200, 200, 200, ..., 189, 190, 190],
#        [200, 199, 199, ..., 190, 190, 190],
#        [199, 199, 199, ..., 190, 190, 190],
#        ...,
#        [ 25,  25,  27, ..., 139, 122, 147],
#        [ 25,  25,  26, ..., 158, 141, 168],
#        [ 25,  25,  27, ..., 151, 152, 149]], dtype=uint8)

# %%
import matplotlib.pyplot as plt
plt.imshow(camera)

# %%
camera[60:200,150:270]
# Out:
# array([[210, 209, 209, ..., 203, 202, 203],
#        [210, 210, 211, ..., 203, 202, 202],
#        [211, 210, 210, ..., 204, 203, 204],
#        ...,
#        [ 30,  28,  28, ..., 146, 145, 146],
#        [ 30,  28,  28, ..., 146, 147, 147],
#        [ 30,  29,  28, ..., 145, 147, 147]], dtype=uint8)

# %% [markdown]
# # **<code>apply()</code>** method applies a function to every row in a pandas dataframe

# %%
df.head()
# Out:
#    id    budget                                             genres  \
# 0   1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1   2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# ...

# %%
def upper_fun(c):
  return c.upper()

# %%
df['upper_title'] = df['original_title'].apply(upper_fun)

# %%
df.head()
# Out:
#    id    budget                                             genres  \
# 0   1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1   2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# ...

# %% [markdown]
# ## Another way to use <code>apply()</code> involves the use of <code>lambda()</code> function.
#
# * ### A <code>lambda()</code> function is a small anonymous function.
# * ### A <code>lambda()</code> function can take any number of arguments, but can only have one expression.

# %%
def add_fun(a,b):
  return a+b

# %%
a = 10
b = 20

add_fun(a,b)
# Out:
# 30

# %%
k = lambda x,y : x+y

# %%
x = 10
y = 200
k(x,y)
# Out:
# 210

# %% [markdown]
# ## We can also sort our dataframe by some column values in either an ascending or descending order

# %%
df['runtime']
# Out:
# 0        93.0
# 1       113.0
# 2       105.0
# 3       122.0
# 4       118.0
#         ...
# 2995    102.0
# 2996    102.0
# 2997    120.0
# 2998     90.0
# 2999    106.0
# Name: runtime, Length: 3000, dtype: float64

# %%
df.sort_values(by = 'runtime', ascending=False)[['title','runtime']]
# Out:
#                                      title  runtime
# 1211                                Carlos    338.0
# 1922                             Cleopatra    248.0
# 523                   The Ten Commandments    220.0
# 1302                         Heaven's Gate    219.0
# 1914                     Gods and Generals    214.0
# ...                                    ...      ...
# 2785                            Revelation      0.0
# 2865             Tutto tutto niente niente      0.0
# 2498  Hooked on the Game 2. The Next Level      0.0
# 1335                               Королёв      NaN
# 2302                         Happy Weekend      NaN
#
# [3000 rows x 2 columns]

# %%
df.sort_values(by = 'profit', ascending=False)[['title','profit']]
# Out:
#                                             title      profit
# 1761                                    Furious 7  1316249360
# 1126                                 The Avengers  1299557910
# 2770                      Avengers: Age of Ultron  1125403694
# 684                          Beauty and the Beast  1102886337
# 2322               Transformers: Dark of the Moon   928746996
# ...                                           ...         ...
# 776                                     Australia   -80445998
# 307                                 Live by Night   -85321445
# 251                              Cutthroat Island   -87982678
# 2278                 The Adventures of Pluto Nash   -92896027
# 2623  Valerian and the City of a Thousand Planets  -107447384
#
# [3000 rows x 2 columns]

# %% [markdown]
# # <b>Let us explore some datetime operations and functions

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3000 non-null   int64
#  1   budget                3000 non-null   int64
#  2   genres                2993 non-null   object
#  3   homepage              946 non-null    object
#  4   imdb_id               3000 non-null   object
#  5   original_language     3000 non-null   object
#  6   original_title        3000 non-null   object
#  7   overview              2992 non-null   object
#  8   popularity            3000 non-null   float64
#  9   poster_path           2999 non-null   object
#  10  production_companies  2844 non-null   object
#  11  production_countries  2945 non-null   object
#  12  release_date          3000 non-null   object
#  13  runtime               2998 non-null   float64
#  14  spoken_languages      2980 non-null   object
# ...

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
# Out:
# <ipython-input-63-bd17abdb2e31>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    3000 non-null   int64
#  1   budget                3000 non-null   int64
#  2   genres                2993 non-null   object
#  3   homepage              946 non-null    object
#  4   imdb_id               3000 non-null   object
#  5   original_language     3000 non-null   object
#  6   original_title        3000 non-null   object
#  7   overview              2992 non-null   object
#  8   popularity            3000 non-null   float64
#  9   poster_path           2999 non-null   object
#  10  production_companies  2844 non-null   object
#  11  production_countries  2945 non-null   object
#  12  release_date          3000 non-null   datetime64[ns]
#  13  runtime               2998 non-null   float64
# ...

# %%
df['release_date'][0]
# Out:
# Timestamp('2015-02-20 00:00:00')

# %%
print(df['release_date'][0].year)
print(df['release_date'][0].month)
print(df['release_date'][0].day)
print(df['release_date'][0].hour)
print(df['release_date'][0].minute)
# Out:
# 2015
# 2
# 20
# 0
# 0

# %%
df['month'] = df['release_date'].dt.month
df['year'] = df['release_date'].dt.year
df['day'] = df['release_date'].dt.day

# %%
df.head()
# Out:
#    id    budget                                             genres  \
# 0   1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1   2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# ...

# %%
# Importing datetime modules
from datetime import datetime
from datetime import date

# %%
print(date.today())
print(datetime.now())
# Out:
# 2024-12-28
# 2024-12-28 15:38:20.208081

# %%
now_utc = pd.Timestamp.now(tz='UTC')
now_ist = now_utc.tz_convert('Asia/Kolkata')

print(now_ist)
# Out:
# 2024-12-28 21:12:18.677038+05:30

# %%
print(df['release_date'][0])
# Out:
# 2015-02-20 00:00:00

# %%
print(df['release_date'][1])
# Out:
# 2004-08-06 00:00:00

# %%
print(df['release_date'][0] - df['release_date'][1])
# Out:
# 3850 days 00:00:00

# %% [markdown]
# # **Let's explore the unique and missing values**
#
# * ### <code>unique()</code>
# * ### <code>nunique()</code>
# * ### <code>value_counts()</code>
# * ### <code>isnull()</code>
# * ### <code>fillna()</code>

# %%
df.head()
# Out:
#    id    budget                                             genres  \
# 0   1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1   2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# ...

# %%
df['original_language'].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
df['original_language'].nunique()
# Out:
# 36

# %%
df['original_language'].value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                         0
# budget                     0
# genres                     7
# homepage                2054
# imdb_id                    0
# original_language          0
# original_title             0
# overview                   8
# popularity                 0
# poster_path                1
# production_companies     156
# production_countries      55
# release_date               0
# runtime                    2
# spoken_languages          20
# status                     0
# tagline                  597
# title                      0
# Keywords                 276
# cast                      13
# crew                      16
# revenue                    0
# profit                     0
# upper_title                0
# month                      0
# year                       0
# day                        0
# dtype: int64

# %%
df['homepage'].isnull().sum()
# Out:
# 2054

# %%
df.head()
# Out:
#    id    budget                                             genres  \
# 0   1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1   2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# ...

# %%
df['homepage'].fillna('not present',inplace=True)
df.head()
# Out:
# <ipython-input-89-b568a9298498>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['homepage'].fillna('not present',inplace=True)
#    id    budget                                             genres  \
# 0   1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1   2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2   3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3   4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# ...

# %%
df['homepage'].isnull().sum()
# Out:
# 0

# %%
df['runtime'].isnull().sum()
# Out:
# 2

# %%
salary = [10,11,10,12,11,12]

avg = sum(salary)/len(salary)

print(avg)
# Out:
# 11.0

# %%
salary = [10,11,10,12,11,12,50]

avg = sum(salary)/len(salary)

print(avg)
# Out:
# 16.571428571428573

# %%
sorted(salary)
# Out:
# [10, 10, 11, 11, 12, 12, 50]

# %%
median = 11

# %%
a = [10,11,10,12,13]
print(sum(a)/len(a))
# Out:
# 11.2

# %%
sorted(a)
# Out:
# [10, 10, 11, 12, 13]

# %%
median = 11

# %%
a = [10,11,10,12,100]
print(sum(a)/len(a))
# Out:
# 28.6

# %%
sorted(a)
# Out:
# [10, 10, 11, 12, 100]

# %%
median = 11

# %%
df['runtime'].mean()
# Out:
# 107.85657104736491

# %%
df['runtime'].median()
# Out:
# 104.0

# %%
df['runtime'].fillna(df['runtime'].median(),inplace=True)
# Out:
# <ipython-input-102-dfb99ec13e94>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['runtime'].fillna(df['runtime'].median(),inplace=True)

# %%
df['runtime'].isnull().sum()
# Out:
# 0

# %%
month = [1,2,1,4,10,12,9,1,2]
print(sum(month)/len(month))
# Out:
# 4.666666666666667

# %%
month = [1,2,1,4,10,12,9,1,2,1]     # we can use here mode because mean is not a integer and median will be approx 15 that that is not a month because month  are 1 to 12 only so we will use here now mode
