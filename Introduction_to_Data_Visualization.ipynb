# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpendracse/DataAnalyst/blob/main/Introduction_to_Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <b><u> A Picture is worth a thousand words! </b></u>

# %% [markdown]
# ## <b> Introducing Matplotlib and Seaborn for data visualization

# %% [markdown]
# ![data_visualization.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Matplotlib.Pyplot
# * One of the core aspects of Matplotlib is matplotlib.pyplot. It is Matplotlib's scripting layer. It is a collection of command style functions that make Matplotlib work like MATLAB. Each pyplot function makes some change to a figure: e.g., creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels, etc. We will work both with the scripting and artist layer.
#
#
# https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html

# %% [markdown]
# ## Let's jump directly onto the data which we will use today for demonstrating the utiltiies of Matplotlib

# %% [markdown]
# * Price Paid Data tracks the residential property sales in England and Wales that are lodged with HM Land Registry for registration.
#
# * The dataset is a reliable source of house price information and consists of more than a million definitive records for the annual year 2018

# %%
import pandas as pd

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Data Set/Copy of Copy of pp-2018.csv'

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data Set/Copy of Copy of pp-2018.csv')

# %%
df.head()
# Out:
#    {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000  2018-01-25 00:00  WR15 8LH  \
# 0  {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000  2018-01-23 00:00   SY7 8QA
# 1  {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000  2018-01-19 00:00   SY1 2BF
# 2  {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000  2018-01-22 00:00   SY8 4DF
# 3  {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000  2018-01-19 00:00  TF10 7ET
# 4  {666758D7-43B4-3363-E053-6B04A8C0D74E}  180000  2018-01-31 00:00   SY3 0NQ
#
#    D  N  F RAMBLERS WAY Unnamed: 8        Unnamed: 9          BORASTON  \
# 0  D  N  F  MONT CENISE        NaN               NaN              CLUN
# 1  T  Y  F           42        NaN        PENSON WAY               NaN
# 2  D  N  F   WILLOW HEY        NaN               NaN  ASHFORD CARBONEL
# 3  D  N  F            3        NaN  PRINCESS GARDENS               NaN
# 4  S  N  F           79        NaN     LYTHWOOD ROAD      BAYSTON HILL
#
#   TENBURY WELLS  SHROPSHIRE SHROPSHIRE.1  A A.1
# ...

# %% [markdown]
# ### Below is a description of the columns/variables in our Price Paid data
#
# * Transaction unique identifier --- A reference number which is generated automatically recording each published sale.
#                                 The number is unique and will change each time a sale is recorded.
# * Price ---- Sale price stated on the transfer deed.
# * Date of Transfer ---- Date when the sale was completed, as stated on the transfer deed.
# * Postcode ---- This is the postcode used at the time of the original transaction. Note that postcodes can be reallocated    and these changes are not reflected in the Price Paid Dataset.
# * Property Type ---- D = Detached, S = Semi-Detached, T = Terraced, F = Flats/Maisonettes, O = Other
# * Newly built  ----- Y = a newly built property, N = an established residential building
# * Duration	Relates to the tenure: F = Freehold, L= Leasehold etc.
#
# * Street
# * Locality
# * Town/City
# * District
# * County
# * PPD Category Type ---- Indicates the type of Price Paid transaction.
#
# * Record Status - monthly file only --- Indicates additions, changes and deletions to the records.(see guide below).
#                                     A = Addition, C = Change, D = Delete.

# %%
df = pd.read_csv(path, names = ["TID","Price","Sale Date", "Postcode",
                                    "Property Type","New Build","Tenure",
                                    "PAON","SAON","Street","Locality",
                                    "Town/City","District","County",
                                    "PPD Category","Record Status"],
                                    parse_dates = ['Sale Date']
                 )

# %%
df.head()
# Out:
#                                       TID   Price  Sale Date  Postcode  \
# 0  {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000 2018-01-25  WR15 8LH
# 1  {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000 2018-01-23   SY7 8QA
# 2  {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000 2018-01-19   SY1 2BF
# 3  {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000 2018-01-22   SY8 4DF
# 4  {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000 2018-01-19  TF10 7ET
#
#   Property Type New Build Tenure          PAON SAON            Street  \
# 0             D         N      F  RAMBLERS WAY  NaN               NaN
# 1             D         N      F   MONT CENISE  NaN               NaN
# 2             T         Y      F            42  NaN        PENSON WAY
# 3             D         N      F    WILLOW HEY  NaN               NaN
# 4             D         N      F             3  NaN  PRINCESS GARDENS
#
#            Locality      Town/City    District      County PPD Category  \
# ...

# %%
df.shape
# Out:
# (1024432, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1024432 entries, 0 to 1024431
# Data columns (total 16 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   TID            1024432 non-null  object
#  1   Price          1024432 non-null  int64
#  2   Sale Date      1024432 non-null  datetime64[ns]
#  3   Postcode       1018507 non-null  object
#  4   Property Type  1024432 non-null  object
#  5   New Build      1024432 non-null  object
#  6   Tenure         1024432 non-null  object
#  7   PAON           1024432 non-null  object
#  8   SAON           140446 non-null   object
#  9   Street         1004772 non-null  object
#  10  Locality       386023 non-null   object
#  11  Town/City      1024432 non-null  object
#  12  District       1024428 non-null  object
#  13  County         1024432 non-null  object
#  14  PPD Category   1024432 non-null  object
#  15  Record Status  1024432 non-null  object
# ...

# %% [markdown]
# * Next we will filter the data to get all the transaction for a particular year and month ( say July 2018 for example). We will only keep transactions of type "A" (Additions) in the data frame and get rid of Changes and Deletions. And for the sake of simplicity we will also remove transactions for property type "O" (Other) and focus only on Detached ("D"), Semi Detached ("S"), Flats ("F") and Terraced ("T") houses.

# %%
df['Record Status'].value_counts()
# Out:
# Record Status
# A    1024432
# Name: count, dtype: int64

# %%
df['Property Type'].value_counts()
# Out:
# Property Type
# T    274610
# S    268026
# D    233324
# F    183043
# O     65429
# Name: count, dtype: int64

# %%
df = df[df['Record Status'] == 'A']
df = df[df['Property Type'] != 'O']

df = df[(df["Sale Date"].dt.year==2018)]

# %%
df.shape
# Out:
# (959003, 16)

# %% [markdown]
# ## First objective : Obtain the trend of sales volume across months

# %%
df.columns
# Out:
# Index(['TID', 'Price', 'Sale Date', 'Postcode', 'Property Type', 'New Build',
#        'Tenure', 'PAON', 'SAON', 'Street', 'Locality', 'Town/City', 'District',
#        'County', 'PPD Category', 'Record Status'],
#       dtype='object')

# %%
df['month'] = df['Sale Date'].dt.month
df['year'] = df['Sale Date'].dt.year
df['day'] = df['Sale Date'].dt.day

# %%
df.head()
# Out:
#                                       TID   Price  Sale Date  Postcode  \
# 0  {666758D7-43A9-3363-E053-6B04A8C0D74E}  405000 2018-01-25  WR15 8LH
# 1  {666758D7-43AA-3363-E053-6B04A8C0D74E}  315000 2018-01-23   SY7 8QA
# 2  {666758D7-43AD-3363-E053-6B04A8C0D74E}  165000 2018-01-19   SY1 2BF
# 3  {666758D7-43B0-3363-E053-6B04A8C0D74E}  370000 2018-01-22   SY8 4DF
# 4  {666758D7-43B3-3363-E053-6B04A8C0D74E}  320000 2018-01-19  TF10 7ET
#
#   Property Type New Build Tenure          PAON SAON            Street  \
# 0             D         N      F  RAMBLERS WAY  NaN               NaN
# 1             D         N      F   MONT CENISE  NaN               NaN
# 2             T         Y      F            42  NaN        PENSON WAY
# 3             D         N      F    WILLOW HEY  NaN               NaN
# 4             D         N      F             3  NaN  PRINCESS GARDENS
#
#            Locality      Town/City    District      County PPD Category  \
# ...

# %%
sale_month = df['month'].value_counts()
sale_month
# Out:
# month
# 8     95382
# 11    92427
# 6     90178
# 10    86892
# 7     83082
# 12    79754
# 3     78070
# 9     77836
# 5     76325
# 4     67094
# 2     66959
# 1     65004
# Name: count, dtype: int64

# %%
sale_month = sale_month.sort_index(ascending = True)
sale_month
# Out:
# month
# 1     65004
# 2     66959
# 3     78070
# 4     67094
# 5     76325
# 6     90178
# 7     83082
# 8     95382
# 9     77836
# 10    86892
# 11    92427
# 12    79754
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = (8, 2)
sale_month.plot(kind = 'bar')
plt.title('Sales Volume Across Months')
plt.xlabel('Month')
plt.ylabel('Sales Volume')
# Out:
# Text(0, 0.5, 'Sales Volume')

# %%
plt.rcParams['figure.figsize'] = (8, 2)
sale_month.plot(kind = 'line')
plt.title('Sales Volume Across Months')
plt.xlabel('Month')
plt.ylabel('Sales Volume')
# Out:
# Text(0, 0.5, 'Sales Volume')

# %%
plt.rcParams['figure.figsize'] = (8, 2)
plt.figure(figsize=(8, 8))
sale_month.plot(kind = 'pie', autopct='%1.0f%%')
plt.title('Sales Volume Across Months')
plt.xlabel('Month')
plt.ylabel('Sales Volume')
# Out:
# Text(0, 0.5, 'Sales Volume')

# %%
plt.rcParams['figure.figsize'] = (8, 2)
sale_month.plot(kind = 'bar',color=sns.color_palette('Set2'))
plt.title('Sales Volume Across Months')
plt.xlabel('Month')
plt.ylabel('Sales Volume')
# Out:
# Text(0, 0.5, 'Sales Volume')

# %%
sns.barplot(sale_month, palette=sns.color_palette('Set2'))
# Out:
# <ipython-input-50-679867cc4bfc>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(sale_month, palette=sns.color_palette('Set2'))
# <ipython-input-50-679867cc4bfc>:1: UserWarning:
# The palette list has fewer values (8) than needed (12) and will cycle, which may produce an uninterpretable plot.
#   sns.barplot(sale_month, palette=sns.color_palette('Set2'))
# <Axes: xlabel='month', ylabel='count'>

# %%
sns.lineplot(sale_month, palette=sns.color_palette('Set2'))
# Out:
# <ipython-input-51-ee5e17538145>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(sale_month, palette=sns.color_palette('Set2'))
# <Axes: xlabel='month', ylabel='count'>

# %% [markdown]
# ## Second objective :  Observe the daily sales volume in the month of July 2018

# %%
juld_df = df[df['month'] == 7]
juld_df['month'].value_counts()
# Out:
# month
# 7    83082
# Name: count, dtype: int64

# %%
juld_df_sale = juld_df['day'].value_counts()
juld_df_sale = juld_df_sale.sort_index(ascending = True)

# %%
juld_df_sale
# Out:
# day
# 1        18
# 2      2931
# 3      1828
# 4      2064
# 5      2358
# 6      8400
# 7        18
# 8        11
# 9      2259
# 10     1985
# 11     2165
# 12     3568
# 13     6561
# 14       25
# 15       20
# 16     2883
# 17     1933
# 18     2438
# 19     2571
# 20     8802
# 21       21
# 22       13
# 23     2742
# 24     2116
# 25     2710
# 26     2965
# 27    11145
# 28       31
# 29       25
# 30     3429
# 31     5047
# Name: count, dtype: int64

# %%
juld_df_sale.plot(kind = 'bar', color = sns.color_palette('Set2'))
# Out:
# <Axes: xlabel='day'>

# %%
juld_df_sale.plot(kind = 'line', color = sns.color_palette('Set2'))
plt.title('Sales Volume Across day in july 2016')
plt.xlabel('day')
plt.ylabel('Sales Volume')
# Out:
# Text(0, 0.5, 'Sales Volume')

# %% [markdown]
# ## Third Objective :  Comparing the daily sales volume of different property types in July

# %%
j_dh = juld_df.groupby(['day','Property Type'])['Property Type'].count().unstack()
j_dh
# Out:
# Property Type     D     F     S     T
# day
# 1                 4     2     7     5
# 2               705   564   782   880
# 3               443   426   436   523
# 4               529   401   528   606
# 5               623   453   614   668
# 6              1955  1662  2422  2361
# 7                 7     6     2     3
# 8                 2     4     1     4
# 9               498   447   638   676
# 10              539   405   498   543
# 11              544   416   633   572
# 12              916   641  1000  1011
# 13             1489  1211  1904  1957
# 14                4     6     9     6
# 15                4     3     5     8
# 16              676   582   828   797
# 17              526   379   499   529
# 18              602   537   662   637
# 19              717   462   699   693
# 20             2017  1476  2626  2683
# 21                3     7     8     3
# 22                3     2     1     7
# 23              631   516   788   807
# ...

# %%
plt.rcParams['figure.figsize'] = (9, 4)
j_dh.plot(kind = 'bar', color = sns.color_palette('Set2'))
# Out:
# <Axes: xlabel='day'>

# %% [markdown]
# ## Fourth Objective :  Draw comparison among different property types in terms of sales

# %%
df['Property Type'].value_counts()
# Out:
# Property Type
# T    274610
# S    268026
# D    233324
# F    183043
# Name: count, dtype: int64

# %% [markdown]
# ## Fourth Objective : Average house prices for different property types in July

# %%
df.groupby('Property Type')['Price'].mean().plot(kind = 'bar', color = sns.color_palette('Set2'))
# Out:
# <Axes: xlabel='Property Type'>

# %%
df.groupby('Property Type')['Price'].sum().plot(kind = 'bar', color = sns.color_palette('Set2'))
# Out:
# <Axes: xlabel='Property Type'>

# %%
df.groupby('Property Type')['Price'].min().plot(kind = 'bar', color = sns.color_palette('Set2'))
# Out:
# <Axes: xlabel='Property Type'>

# %%
df.groupby('Property Type')['Price'].max().plot(kind = 'bar', color = sns.color_palette('Set2'))
# Out:
# <Axes: xlabel='Property Type'>

# %% [markdown]
# ## Box plot
#
# * Also called as **box and whisker plot**, is a way of showing the distribution of data in a five-number summary.
#
# * Below we will create a box plot which shows the price distribution for all the four different property types.

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: ylabel='Price'>

# %%
df1 = pd.DataFrame([10,11,12,10,20],columns = ['price'])
df1.head()
# Out:
#    price
# 0     10
# 1     11
# 2     12
# 3     10
# 4     20

# %%
sns.boxplot(df1['price'])
# Out:
# <Axes: ylabel='price'>

# %% [markdown]
# # Histogram

# %%
sns.distplot(df['Price'])
# Out:
# <ipython-input-84-87e11caeb2c4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
df1 = pd.DataFrame([10,10,10,11,11,12,10,20],columns = ['price'])
df1.head()
# Out:
#    price
# 0     10
# 1     10
# 2     10
# 3     11
# 4     11

# %%
sns.distplot(df1['price'])
# Out:
# <ipython-input-87-193938add8a7>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['price'])
# <Axes: xlabel='price', ylabel='Density'>

# %%
path = '/content/drive/MyDrive/Colab Notebooks/Data Set/Copy of Copy of Speed Dating Data.csv'

dating_data = pd.read_csv(path, encoding = 'ISO-8859-1')

# %%
dating_data.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
dating_data.shape
# Out:
# (8378, 195)

# %%
dating_data['age']
# Out:
# 0       21.0
# 1       21.0
# 2       21.0
# 3       21.0
# 4       21.0
#         ...
# 8373    25.0
# 8374    25.0
# 8375    25.0
# 8376    25.0
# 8377    25.0
# Name: age, Length: 8378, dtype: float64

# %%
sns.distplot(dating_data['age'])
# Out:
# <ipython-input-93-cb7825a379a3>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dating_data['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %% [markdown]
# # Understanding correlation

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
dating_data = dating_data[['gender', 'shopping', 'gaming', 'concerts', 'music']]
dating_data
# Out:
#       gender  shopping  gaming  concerts  music
# 0          0       8.0     1.0      10.0    9.0
# 1          0       8.0     1.0      10.0    9.0
# 2          0       8.0     1.0      10.0    9.0
# 3          0       8.0     1.0      10.0    9.0
# 4          0       8.0     1.0      10.0    9.0
# ...      ...       ...     ...       ...    ...
# 8373       1       7.0     1.0      10.0   10.0
# 8374       1       7.0     1.0      10.0   10.0
# 8375       1       7.0     1.0      10.0   10.0
# 8376       1       7.0     1.0      10.0   10.0
# 8377       1       7.0     1.0      10.0   10.0
#
# [8378 rows x 5 columns]

# %%
dating_data.corr()
# Out:
#             gender  shopping    gaming  concerts     music
# gender    1.000000 -0.330718  0.219619 -0.128339 -0.076850
# shopping -0.330718  1.000000  0.093467  0.205389  0.208329
# gaming    0.219619  0.093467  1.000000  0.098806  0.043301
# concerts -0.128339  0.205389  0.098806  1.000000  0.655728
# music    -0.076850  0.208329  0.043301  0.655728  1.000000

# %%
sns.heatmap(dating_data.corr(),annot = True)
# Out:
# <Axes: >

# %%
sns.heatmap(dating_data.corr())
# Out:
# <Axes: >

# %%
not_null_genere = df[df['genres'].notnull()]
not_null_genere['genres'].isnull().sum()

# %%
genere = []
for i in not_null_genere['genres']:
 for j in eval(i):
 genere.append(j['name'])

print(genere)

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### You are given a list of urls. You need to extract the domain name from the urls in another list. Also you need to extract the ending string which the url ends with.
#
# ### For example, https://www.example.com/market.php -- In this example, domain name is <code>www.example.com</code> and the ending string is <code>php</code>

# %%
# List of urls
url_list = ['https://blog.hubspot.com/marketing/parts-url',
            'https://www.google.com/enrollments',
            'https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html',
            'https://www.programiz.com/python-programming/list']

# %% [markdown]
# # <u>**Problem 1**</u>
#
# ### You are given a list of urls. You need to extract the domain name from the urls in another list. Also you need to extract the ending string which the url ends with.
#
# ### For example, https://www.example.com/market.php -- In this example, domain name is <code>www.example.com</code> and the ending string is <code>php</code>

# %%
# List of urls
url_list = ['https://blog.hubspot.com/marketing/parts-url',
            'https://www.google.com/enrollments',
            'https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html',
            'https://www.programiz.com/python-programming/list']

# %%
domain = []
Ending_string = []
for i in url_list:
  domain.append(i.split('/')[2])

  Ending_string.append(i.split('/')[-1].split('.')[-1])

print(domain)
print(Ending_string)
# Out:
# ['blog.hubspot.com', 'www.google.com', 'pandas.pydata.org', 'www.programiz.com']
# ['parts-url', 'enrollments', 'html', 'list']

# %%
df = pd.DataFrame({'url':url_list,'domain':domain,'Ending_string':Ending_string})
df
# Out:
#                                                  url             domain  \
# 0       https://blog.hubspot.com/marketing/parts-url   blog.hubspot.com
# 1                 https://www.google.com/enrollments     www.google.com
# 2  https://pandas.pydata.org/pandas-docs/stable/r...  pandas.pydata.org
# 3  https://www.programiz.com/python-programming/list  www.programiz.com
#
#   Ending_string
# 0     parts-url
# 1   enrollments
# 2          html
# 3          list

# %%
df
# Out:
#                                                  Url              Domain  \
# 0       https://blog.hubspot.com/marketing/parts-url    blog.hubspot.com
# 1             https://www.almabetter.com/enrollments  www.almabetter.com
# 2  https://pandas.pydata.org/pandas-docs/stable/r...   pandas.pydata.org
# 3  https://www.programiz.com/python-programming/list   www.programiz.com
#
#   Ending_string
# 0     parts-url
# 1   enrollments
# 2          html
# 3          list
